# %% [markdown]
# **DECOMPOSING TIME SERIES**

# %%
import pandas as pd

# %%
df = pd.read_csv('us-airlines-monthly-aircraft-miles-flown.csv', header=0, parse_dates=[0])
df.head()
# Out:
#        Month  MilesMM
# 0 1963-01-01     6827
# 1 1963-02-01     6178
# 2 1963-03-01     7084
# 3 1963-04-01     8162
# 4 1963-05-01     8462

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
df.index = df['Month']
df.head()
# Out:
#                 Month  MilesMM
# Month
# 1963-01-01 1963-01-01     6827
# 1963-02-01 1963-02-01     6178
# 1963-03-01 1963-03-01     7084
# 1963-04-01 1963-04-01     8162
# 1963-05-01 1963-05-01     8462

# %%
decompose1 = seasonal_decompose(df['MilesMM'], model='additive')
decompose1.plot()

# %%
decompose2 = seasonal_decompose(df['MilesMM'], model='multiplicative')
decompose2.plot()
